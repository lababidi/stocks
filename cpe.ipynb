# %%
from keys import api_key, secret

# %%
import alpaca_trade_api as tradeapi

api = tradeapi.REST(api_key, secret, "https://paper-api.alpaca.markets")

# Get daily price data for AAPL over the last 5 trading days.
barset = api.get_bars('AAPL', tradeapi.TimeFrame.Minute, "2021-01-01")
# aapl_bars = barset['AAPL']

# # See how much AAPL moved in that timeframe.
# week_open = aapl_bars[0].o
# week_close = aapl_bars[-1].c
# percent_change = (week_close - week_open) / week_open * 100
# print('AAPL moved {}% over the last 5 days'.format(percent_change))

# %%
barset
# Out:
# [Bar({   'c': 133.49,
#      'h': 133.49,
#      'l': 133.02,
#      'n': 87,
#      'o': 133.31,
#      't': '2021-01-04T09:00:00Z',
#      'v': 26666,
#      'vw': 133.233024}),
#  Bar({   'c': 133.49,
#      'h': 133.49,
#      'l': 133.49,
#      'n': 26,
#      'o': 133.49,
#      't': '2021-01-04T09:01:00Z',
#      'v': 1240,
#      'vw': 133.490887}),
#  Bar({   'c': 133.5,
#      'h': 133.6,
#      'l': 133.5,
#      'n': 30,
#      'o': 133.6,
#      't': '2021-01-04T09:02:00Z',
#      'v': 1217,
#      'vw': 133.523558}),
#  Bar({   'c': 133.51,
#      'h': 133.51,
#      'l': 133.51,
#      'n': 18,
#      'o': 133.51,
#      't': '2021-01-04T09:03:00Z',
#      'v': 741,
#      'vw': 133.569825}),
#  Bar({   'c': 133.72,
#      'h': 133.77,
#      'l': 133.7,
#      'n': 30,
#      'o': 133.77,
#      't': '2021-01-04T09:04:00Z',
#      'v': 1970,
#      'vw': 133.725553}),
#  Bar({   'c': 133.74,
#      'h': 133.74,
#      'l': 133.71,
#      'n': 23,
#      'o': 133.71,
#      't': '2021-01-04T09:05:00Z',
#      'v': 973,
#      'vw': 133.731213}),
#  Bar({   'c': 133.72,
#      'h': 133.76,
#      'l': 133.72,
#      'n': 39,
#      'o': 133.75,
#      't': '2021-01-04T09:06:00Z',
#      'v': 2200,
#      'vw': 133.736773}),
#  Bar({   'c': 133.8,
#      'h': 133.85,
#      'l': 133.77,
#      'n': 35,
#      'o': 133.77,
#      't': '2021-01-04T09:07:00Z',
#      'v': 4015,
#      'vw': 133.819103}),
#  Bar({   'c': 133.9,
#      'h': 133.9,
#      'l': 133.89,
#      'n': 32,
#      'o': 133.89,
#      't': '2021-01-04T09:08:00Z',
#      'v': 1243,
#      'vw': 133.88387}),
#  Bar({   'c': 133.98,
#      'h': 133.98,
#      'l': 133.89,
#      'n': 49,
#      'o': 133.9,
#      't': '2021-01-04T09:09:00Z',
#      'v': 2899,
#      'vw': 133.931566}),
#  Bar({   'c': 133.98,
#      'h': 133.98,
#      'l': 133.98,
#      'n': 21,
#      'o': 133.98,
#      't': '2021-01-04T09:10:00Z',
#      'v': 641,
#      'vw': 133.981186}),
#  Bar({   'c': 133.96,
#      'h': 134,
#      'l': 133.96,
#      'n': 35,
#      'o': 133.97,
#      't': '2021-01-04T09:11:00Z',
#      'v': 3193,
#      'vw': 133.985077}),
#  Bar({   'c': 133.9,
#      'h': 133.93,
#      'l': 133.9,
#      'n': 29,
#      'o': 133.93,
#      't': '2021-01-04T09:12:00Z',
#      'v': 1497,
#      'vw': 133.911349}),
#  Bar({   'c': 133.85,
#      'h': 133.89,
#      'l': 133.85,
#      'n': 28,
#      'o': 133.89,
#      't': '2021-01-04T09:13:00Z',
#      'v': 924,
#      'vw': 133.879091}),
#  Bar({   'c': 133.74,
#      'h': 133.82,
#      'l': 133.74,
#      'n': 41,
#      'o': 133.82,
#      't': '2021-01-04T09:14:00Z',
#      'v': 2409,
#      'vw': 133.778871}),
#  Bar({   'c': 134,
#      'h': 134,
#      'l': 133.98,
#      'n': 43,
#      'o': 133.98,
#      't': '2021-01-04T09:16:00Z',
#      'v': 1867,
#      'vw': 133.939673}),
#  Bar({   'c': 134,
#      'h': 134.01,
#      'l': 133.96,
#      'n': 30,
#      'o': 134,
#      't': '2021-01-04T09:17:00Z',
#      'v': 2324,
#      'vw': 133.999871}),
#  Bar({   'c': 133.96,
#      'h': 134,
#      'l': 133.96,
#      'n': 19,
#      'o': 134,
#      't': '2021-01-04T09:18:00Z',
#      'v': 19938,
#      'vw': 133.999817}),
#  Bar({   'c': 133.95,
#      'h': 133.95,
#      'l': 133.94,
#      'n': 19,
#      'o': 133.94,
#      't': '2021-01-04T09:19:00Z',
#      'v': 1021,
#      'vw': 133.94476}),
#  Bar({   'c': 133.9,
#      'h': 133.95,
#      'l': 133.9,
#      'n': 22,
#      'o': 133.9,
#      't': '2021-01-04T09:20:00Z',
#      'v': 1434,
#      'vw': 133.909379}),
#  Bar({   'c': 133.83,
#      'h': 133.83,
#      'l': 133.83,
#      'n': 20,
#      'o': 133.83,
#      't': '2021-01-04T09:21:00Z',
#      'v': 861,
#      'vw': 133.859744}),
#  Bar({   'c': 133.88,
#      'h': 133.89,
#      'l': 133.88,
#      'n': 24,
#      'o': 133.89,
#      't': '2021-01-04T09:27:00Z',
#      'v': 699,
#      'vw': 133.894993}),
#  Bar({   'c': 134,
#      'h': 134,
#      'l': 133.88,
#      'n': 30,
#      'o': 133.88,
#      't': '2021-01-04T09:28:00Z',
#      'v': 2023,
#      'vw': 133.920682}),
#  Bar({   'c': 134,
#      'h': 134,
#      'l': 133.99,
#      'n': 24,
#      'o': 133.99,
#      't': '2021-01-04T09:29:00Z',
#      'v': 1040,
#      'vw': 133.99001}),
#  Bar({   'c': 134,
#      'h': 134,
#      'l': 134,
#      'n': 11,
#      'o': 134,
#      't': '2021-01-04T09:31:00Z',
#      'v': 323,
#      'vw': 133.997368}),
#  Bar({   'c': 133.93,
#      'h': 134,
#      'l': 133.93,
#      'n': 29,
#      'o': 134,
#      't': '2021-01-04T09:32:00Z',
#      'v': 2752,
#      'vw': 133.983525}),
#  Bar({   'c': 133.91,
#      'h': 133.91,
#      'l': 133.91,
#      'n': 14,
#      'o': 133.91,
#      't': '2021-01-04T09:33:00Z',
#      'v': 430,
#      'vw': 133.937907}),
#  Bar({   'c': 133.96,
#      'h': 133.96,
#      'l': 133.96,
#      'n': 8,
#      'o': 133.96,
#      't': '2021-01-04T09:35:00Z',
#      'v': 245,
#      'vw': 133.961102}),
#  Bar({   'c': 133.95,
#      'h': 133.95,
#      'l': 133.95,
#      'n': 11,
#      'o': 133.95,
#      't': '2021-01-04T09:36:00Z',
#      'v': 250,
#      'vw': 133.95676}),
#  Bar({   'c': 133.93,
#      'h': 133.95,
#      'l': 133.93,
#      'n': 21,
#      'o': 133.95,
#      't': '2021-01-04T09:37:00Z',
#      'v': 855,
#      'vw': 133.958971}),
#  Bar({   'c': 133.9,
#      'h': 133.9,
#      'l': 133.9,
#      'n': 17,
#      'o': 133.9,
#      't': '2021-01-04T09:38:00Z',
#      'v': 875,
#      'vw': 133.903451}),
#  Bar({   'c': 133.85,
#      'h': 133.9,
#      'l': 133.55,
#      'n': 54,
#      'o': 133.9,
#      't': '2021-01-04T09:41:00Z',
#      'v': 3029,
#      'vw': 133.837811}),
#  Bar({   'c': 133.85,
#      'h': 133.85,
#      'l': 133.85,
#      'n': 20,
#      'o': 133.85,
#      't': '2021-01-04T09:42:00Z',
#      'v': 1003,
#      'vw': 133.850429}),
#  Bar({   'c': 133.85,
#      'h': 133.85,
#      'l': 133.85,
#      'n': 19,
#      'o': 133.85,
#      't': '2021-01-04T09:43:00Z',
#      'v': 838,
#      'vw': 133.853556}),
#  Bar({   'c': 133.61,
#      'h': 133.86,
#      'l': 133.61,
#      'n': 72,
#      'o': 133.86,
#      't': '2021-01-04T09:45:00Z',
#      'v': 4562,
#      'vw': 133.738799}),
#  Bar({   'c': 133.59,
#      'h': 133.6,
#      'l': 133.59,
#      'n': 17,
#      'o': 133.6,
#      't': '2021-01-04T09:46:00Z',
#      'v': 648,
#      'vw': 133.590201}),
#  Bar({   'c': 133.6,
#      'h': 133.6,
#      'l': 133.6,
#      'n': 28,
#      'o': 133.6,
#      't': '2021-01-04T09:47:00Z',
#      'v': 2942,
#      'vw': 133.599725}),
#  Bar({   'c': 133.58,
#      'h': 133.58,
#      'l': 133.5,
#      'n': 29,
#      'o': 133.55,
#      't': '2021-01-04T09:49:00Z',
#      'v': 2357,
#      'vw': 133.54319}),
#  Bar({   'c': 133.6,
#      'h': 133.6,
#      'l': 133.6,
#      'n': 12,
#      'o': 133.6,
#      't': '2021-01-04T09:51:00Z',
#      'v': 888,
#      'vw': 133.599065}),
#  Bar({   'c': 133.6,
#      'h': 133.6,
#      'l': 133.6,
#      'n': 21,
#      'o': 133.6,
#      't': '2021-01-04T09:52:00Z',
#      'v': 619,
#      'vw': 133.597722}),
#  Bar({   'c': 133.51,
#      'h': 133.52,
#      'l': 133.51,
#      'n': 30,
#      'o': 133.52,
#      't': '2021-01-04T09:53:00Z',
#      'v': 740,
#      'vw': 133.52723}),
#  Bar({   'c': 133.6,
#      'h': 133.6,
#      'l': 133.5,
#      'n': 34,
#      'o': 133.52,
#      't': '2021-01-04T09:54:00Z',
#      'v': 3074,
#      'vw': 133.57756}),
#  Bar({   'c': 133.58,
#      'h': 133.58,
#      'l': 133.58,
#      'n': 14,
#      'o': 133.58,
#      't': '2021-01-04T09:56:00Z',
#      'v': 240,
#      'vw': 133.583875}),
#  Bar({   'c': 133.6,
#      'h': 133.6,
#      'l': 133.6,
#      'n': 18,
#      'o': 133.6,
#      't': '2021-01-04T09:58:00Z',
#      'v': 398,
#      'vw': 133.599774}),
#  Bar({   'c': 133.6,
#      'h': 133.6,
#      'l': 133.6,
#      'n': 23,
#      'o': 133.6,
#      't': '2021-01-04T09:59:00Z',
#      'v': 2026,
#      'vw': 133.598465}),
#  Bar({   'c': 133.6,
#      'h': 133.6,
#      'l': 133.6,
#      'n': 18,
#      'o': 133.6,
#      't': '2021-01-04T10:00:00Z',
#      'v': 18823,
#      'vw': 133.601047}),
#  Bar({   'c': 133.85,
#      'h': 133.85,
#      'l': 133.84,
#      'n': 9,
#      'o': 133.84,
#      't': '2021-01-04T10:01:00Z',
#      'v': 300,
#      'vw': 133.843733}),
#  Bar({   'c': 133.86,
#      'h': 133.88,
#      'l': 133.85,
#      'n': 23,
#      'o': 133.88,
#      't': '2021-01-04T10:02:00Z',
#      'v': 989,
#      'vw': 133.856906}),
#  Bar({   'c': 133.9,
#      'h': 133.95,
#      'l': 133.86,
#      'n': 27,
#      'o': 133.86,
#      't': '2021-01-04T10:04:00Z',
#      'v': 1749,
#      'vw': 133.895043}),
#  Bar({   'c': 133.81,
#      'h': 133.86,
#      'l': 133.8,
#      'n': 22,
#      'o': 133.8,
#      't': '2021-01-04T10:05:00Z',
#      'v': 1123,
#      'vw': 133.817845}),
#  Bar({   'c': 133.81,
#      'h': 133.81,
#      'l': 133.81,
#      'n': 17,
#      'o': 133.81,
#      't': '2021-01-04T10:06:00Z',
#      'v': 277,
#      'vw': 133.806751}),
#  Bar({   'c': 133.81,
#      'h': 133.81,
#      'l': 133.81,
#      'n': 26,
#      'o': 133.81,
#      't': '2021-01-04T10:07:00Z',
#      'v': 476,
#      'vw': 133.807311}),
#  Bar({   'c': 133.81,
#      'h': 133.81,
#      'l': 133.8,
#      'n': 25,
#      'o': 133.8,
#      't': '2021-01-04T10:08:00Z',
#      'v': 1323,
#      'vw': 133.809494}),
#  Bar({   'c': 133.69,
#      'h': 133.69,
#      'l': 133.69,
#      'n': 14,
#      'o': 133.69,
#      't': '2021-01-04T10:10:00Z',
#      'v': 683,
#      'vw': 133.683221}),
#  Bar({   'c': 133.66,
#      'h': 133.66,
#      'l': 133.6,
#      'n': 29,
#      'o': 133.65,
#      't': '2021-01-04T10:11:00Z',
#      'v': 6642,
#      'vw': 133.607445}),
#  Bar({   'c': 133.6,
#      'h': 133.6,
#      'l': 133.6,
#      'n': 11,
#      'o': 133.6,
#      't': '2021-01-04T10:12:00Z',
#      'v': 1416,
#      'vw': 133.601582}),
#  Bar({   'c': 133.6,
#      'h': 133.6,
#      'l': 133.6,
#      'n': 25,
#      'o': 133.6,
#      't': '2021-01-04T10:14:00Z',
#      'v': 992,
#      'vw': 133.60253}),
#  Bar({   'c': 133.68,
#      'h': 133.68,
#      'l': 133.68,
#      'n': 14,
#      'o': 133.68,
#      't': '2021-01-04T10:15:00Z',
#      'v': 364,
#      'vw': 133.659368}),
#  Bar({   'c': 133.65,
#      'h': 133.65,
#      'l': 133.65,
#      'n': 11,
#      'o': 133.65,
#      't': '2021-01-04T10:16:00Z',
#      'v': 550,
#      'vw': 133.648473}),
#  Bar({   'c': 133.62,
#      'h': 133.62,
#      'l': 133.61,
#      'n': 18,
#      'o': 133.61,
#      't': '2021-01-04T10:17:00Z',
#      'v': 2717,
#      'vw': 133.618936}),
#  Bar({   'c': 133.6,
#      'h': 133.62,
#      'l': 133.6,
#      'n': 32,
#      'o': 133.62,
#      't': '2021-01-04T10:18:00Z',
#      'v': 2166,
#      'vw': 133.609229}),
#  Bar({   'c': 133.54,
#      'h': 133.54,
#      'l': 133.53,
#      'n': 41,
#      'o': 133.53,
#      't': '2021-01-04T10:19:00Z',
#      'v': 1249,
#      'vw': 133.559984}),
#  Bar({   'c': 133.47,
#      'h': 133.5,
#      'l': 133.47,
#      'n': 49,
#      'o': 133.5,
#      't': '2021-01-04T10:21:00Z',
#      'v': 1876,
#      'vw': 133.495229}),
#  Bar({   'c': 133.43,
#      'h': 133.5,
#      'l': 133.43,
#      'n': 27,
#      'o': 133.5,
#      't': '2021-01-04T10:22:00Z',
#      'v': 733,
#      'vw': 133.464488}),
#  Bar({   'c': 133.5,
#      'h': 133.5,
#      'l': 133.5,
#      'n': 14,
#      'o': 133.5,
#      't': '2021-01-04T10:23:00Z',
#      'v': 956,
#      'vw': 133.512824}),
#  Bar({   'c': 133.53,
#      'h': 133.54,
#      'l': 133.53,
#      'n': 10,
#      'o': 133.54,
#      't': '2021-01-04T10:24:00Z',
#      'v': 1151,
#      'vw': 133.538358}),
#  Bar({   'c': 133.54,
#      'h': 133.54,
#      'l': 133.54,
#      'n': 26,
#      'o': 133.54,
#      't': '2021-01-04T10:25:00Z',
#      'v': 735,
#      'vw': 133.554707}),
#  Bar({   'c': 133.54,
#      'h': 133.55,
#      'l': 133.53,
#      'n': 34,
#      'o': 133.54,
#      't': '2021-01-04T10:26:00Z',
#      'v': 1238,
#      'vw': 133.53916}),
#  Bar({   'c': 133.53,
#      'h': 133.54,
#      'l': 133.53,
#      'n': 31,
#      'o': 133.53,
#      't': '2021-01-04T10:27:00Z',
#      'v': 7219,
#      'vw': 133.530979}),
#  Bar({   'c': 133.6,
#      'h': 133.6,
#      'l': 133.59,
#      'n': 9,
#      'o': 133.59,
#      't': '2021-01-04T10:31:00Z',
#      'v': 1387,
#      'vw': 133.595984}),
#  Bar({   'c': 133.8,
#      'h': 133.8,
#      'l': 133.76,
#      'n': 22,
#      'o': 133.76,
#      't': '2021-01-04T10:34:00Z',
#      'v': 1613,
#      'vw': 133.783707}),
#  Bar({   'c': 133.95,
#      'h': 133.95,
#      'l': 133.77,
#      'n': 27,
#      'o': 133.77,
#      't': '2021-01-04T10:36:00Z',
#      'v': 7225,
#      'vw': 133.91108}),
#  Bar({   'c': 133.95,
#      'h': 134.05,
#      'l': 133.92,
#      'n': 38,
#      'o': 133.94,
#      't': '2021-01-04T10:37:00Z',
#      'v': 4856,
#      'vw': 133.991114}),
#  Bar({   'c': 134.2,
#      'h': 134.2,
#      'l': 134,
#      'n': 36,
#      'o': 134,
#      't': '2021-01-04T10:38:00Z',
#      'v': 3702,
#      'vw': 134.089824}),
#  Bar({   'c': 134.23,
#      'h': 134.29,
#      'l': 134.09,
#      'n': 47,
#      'o': 134.09,
#      't': '2021-01-04T10:39:00Z',
#      'v': 21127,
#      'vw': 134.227471}),
#  Bar({   'c': 134.15,
#      'h': 134.16,
#      'l': 134.05,
#      'n': 25,
#      'o': 134.15,
#      't': '2021-01-04T10:40:00Z',
#      'v': 2926,
#      'vw': 134.122037}),
#  Bar({   'c': 134.34,
#      'h': 134.34,
#      'l': 134.2,
#      'n': 43,
#      'o': 134.2,
#      't': '2021-01-04T10:41:00Z',
#      'v': 6660,
#      'vw': 134.27789}),
#  Bar({   'c': 134.42,
#      'h': 134.43,
#      'l': 134.29,
#      'n': 22,
#      'o': 134.29,
#      't': '2021-01-04T10:42:00Z',
#      'v': 2997,
#      'vw': 134.390774}),
#  Bar({   'c': 134.43,
#      'h': 134.43,
#      'l': 134.4,
#      'n': 19,
#      'o': 134.41,
#      't': '2021-01-04T10:43:00Z',
#      'v': 2215,
#      'vw': 134.419675}),
#  Bar({   'c': 134.31,
#      'h': 134.42,
#      'l': 134.31,
#      'n': 27,
#      'o': 134.42,
#      't': '2021-01-04T10:44:00Z',
#      'v': 4106,
#      'vw': 134.325916}),
#  Bar({   'c': 134.31,
#      'h': 134.31,
#      'l': 134.31,
#      'n': 17,
#      'o': 134.31,
#      't': '2021-01-04T10:45:00Z',
#      'v': 824,
#      'vw': 134.312512}),
#  Bar({   'c': 134.31,
#      'h': 134.31,
#      'l': 134.29,
#      'n': 10,
#      'o': 134.29,
#      't': '2021-01-04T10:46:00Z',
#      'v': 715,
#      'vw': 134.294713}),
#  Bar({   'c': 134.37,
#      'h': 134.37,
#      'l': 134.31,
#      'n': 14,
#      'o': 134.31,
#      't': '2021-01-04T10:47:00Z',
#      'v': 487,
#      'vw': 134.356181}),
#  Bar({   'c': 134.31,
#      'h': 134.34,
#      'l': 134.31,
#      'n': 26,
#      'o': 134.34,
#      't': '2021-01-04T10:48:00Z',
#      'v': 1479,
#      'vw': 134.316214}),
#  Bar({   'c': 134.41,
#      'h': 134.41,
#      'l': 134.24,
#      'n': 47,
#      'o': 134.24,
#      't': '2021-01-04T10:49:00Z',
#      'v': 5955,
#      'vw': 134.35445}),
#  Bar({   'c': 134.4,
#      'h': 134.4,
#      'l': 134.4,
#      'n': 12,
#      'o': 134.4,
#      't': '2021-01-04T10:50:00Z',
#      'v': 374,
#      'vw': 134.39385}),
#  Bar({   'c': 134.36,
#      'h': 134.39,
#      'l': 134.36,
#      'n': 17,
#      'o': 134.37,
#      't': '2021-01-04T10:51:00Z',
#      'v': 31365,
#      'vw': 134.360367}),
#  Bar({   'c': 134.3,
#      'h': 134.3,
#      'l': 134.24,
#      'n': 17,
#      'o': 134.24,
#      't': '2021-01-04T10:52:00Z',
#      'v': 712,
#      'vw': 134.273497}),
#  Bar({   'c': 134.29,
#      'h': 134.29,
#      'l': 134.29,
#      'n': 6,
#      'o': 134.29,
#      't': '2021-01-04T10:53:00Z',
#      'v': 261,
#      'vw': 134.291494}),
#  Bar({   'c': 134.27,
#      'h': 134.27,
#      'l': 134.26,
#      'n': 8,
#      'o': 134.26,
#      't': '2021-01-04T10:54:00Z',
#      'v': 279,
#      'vw': 134.264086}),
#  Bar({   'c': 134.33,
#      'h': 134.33,
#      'l': 134.29,
#      'n': 13,
#      'o': 134.29,
#      't': '2021-01-04T10:55:00Z',
#      'v': 642,
#      'vw': 134.305202}),
#  Bar({   'c': 134.31,
#      'h': 134.32,
#      'l': 134.31,
#      'n': 20,
#      'o': 134.32,
#      't': '2021-01-04T10:56:00Z',
#      'v': 2179,
#      'vw': 134.311978}),
#  Bar({   'c': 134.4,
#      'h': 134.42,
#      'l': 134.3,
#      'n': 26,
#      'o': 134.31,
#      't': '2021-01-04T10:57:00Z',
#      'v': 2959,
#      'vw': 134.378273}),
#  Bar({   'c': 134.33,
#      'h': 134.33,
#      'l': 134.33,
#      'n': 9,
#      'o': 134.33,
#      't': '2021-01-04T10:58:00Z',
#      'v': 249,
#      'vw': 134.329558}),
#  Bar({   'c': 134.3,
#      'h': 134.3,
#      'l': 134.3,
#      'n': 14,
#      'o': 134.3,
#      't': '2021-01-04T10:59:00Z',
#      'v': 216,
#      'vw': 134.305787}),
#  Bar({   'c': 134.28,
#      'h': 134.28,
#      'l': 134.18,
#      'n': 25,
#      'o': 134.22,
#      't': '2021-01-04T11:00:00Z',
#      'v': 1669,
#      'vw': 134.258214}),
#  Bar({   'c': 134.17,
#      'h': 134.18,
#      'l': 134.17,
#      'n': 10,
#      'o': 134.18,
#      't': '2021-01-04T11:02:00Z',
#      'v': 546,
#      'vw': 134.181044}),
#  Bar({   'c': 134.3,
#      'h': 134.3,
#      'l': 134.28,
#      'n': 7,
#      'o': 134.28,
#      't': '2021-01-04T11:03:00Z',
#      'v': 489,
#      'vw': 134.294683}),
#  Bar({   'c': 134.3,
#      'h': 134.32,
#      'l': 134.3,
#      'n': 17,
#      'o': 134.32,
#      't': '2021-01-04T11:04:00Z',
#      'v': 2035,
#      'vw': 134.309538}),
#  Bar({   'c': 134.32,
#      'h': 134.32,
#      'l': 134.3,
#      'n': 8,
#      'o': 134.3,
#      't': '2021-01-04T11:05:00Z',
#      'v': 1161,
#      'vw': 134.317537}),
#  Bar({   'c': 134.35,
#      'h': 134.35,
#      'l': 134.35,
#      'n': 8,
#      'o': 134.35,
#      't': '2021-01-04T11:06:00Z',
#      'v': 1160,
#      'vw': 134.348164}),
#  Bar({   'c': 134.25,
#      'h': 134.25,
#      'l': 134.25,
#      'n': 28,
#      'o': 134.25,
#      't': '2021-01-04T11:10:00Z',
#      'v': 841,
#      'vw': 134.283401}),
#  Bar({   'c': 134.23,
#      'h': 134.35,
#      'l': 134.23,
#      'n': 33,
#      'o': 134.23,
#      't': '2021-01-04T11:11:00Z',
#      'v': 1891,
#      'vw': 134.303194}),
#  Bar({   'c': 134.22,
#      'h': 134.22,
#      'l': 134.22,
#      'n': 18,
#      'o': 134.22,
#      't': '2021-01-04T11:12:00Z',
#      'v': 381,
#      'vw': 134.247507}),
#  Bar({   'c': 134.1,
#      'h': 134.2,
#      'l': 134.1,
#      'n': 21,
#      'o': 134.2,
#      't': '2021-01-04T11:15:00Z',
#      'v': 1268,
#      'vw': 134.143636}),
#  Bar({   'c': 134.1,
#      'h': 134.1,
#      'l': 134.08,
#      'n': 13,
#      'o': 134.08,
#      't': '2021-01-04T11:16:00Z',
#      'v': 554,
#      'vw': 134.130993}),
#  Bar({   'c': 134.2,
#      'h': 134.2,
#      'l': 134.2,
#      'n': 13,
#      'o': 134.2,
#      't': '2021-01-04T11:17:00Z',
#      'v': 638,
#      'vw': 134.19594}),
#  Bar({   'c': 134.11,
#      'h': 134.11,
#      'l': 134.11,
#      'n': 22,
#      'o': 134.11,
#      't': '2021-01-04T11:18:00Z',
#      'v': 802,
#      'vw': 134.110324}),
#  Bar({   'c': 134.16,
#      'h': 134.16,
#      'l': 134.16,
#      'n': 7,
#      'o': 134.16,
#      't': '2021-01-04T11:19:00Z',
#      'v': 225,
#      'vw': 134.159067}),
#  Bar({   'c': 134.15,
#      'h': 134.15,
#      'l': 134.15,
#      'n': 7,
#      'o': 134.15,
#      't': '2021-01-04T11:21:00Z',
#      'v': 273,
#      'vw': 134.146337}),
#  Bar({   'c': 134.05,
#      'h': 134.15,
#      'l': 134.05,
#      'n': 17,
#      'o': 134.15,
#      't': '2021-01-04T11:22:00Z',
#      'v': 891,
#      'vw': 134.106745}),
#  Bar({   'c': 134.1,
#      'h': 134.1,
#      'l': 134.1,
#      'n': 7,
#      'o': 134.1,
#      't': '2021-01-04T11:25:00Z',
#      'v': 437,
#      'vw': 134.101648}),
#  Bar({   'c': 134.1,
#      'h': 134.1,
#      'l': 134.1,
#      'n': 19,
#      'o': 134.1,
#      't': '2021-01-04T11:27:00Z',
#      'v': 521,
#      'vw': 134.118081}),
#  Bar({   'c': 134.25,
#      'h': 134.25,
#      'l': 134.19,
#      'n': 20,
#      'o': 134.19,
#      't': '2021-01-04T11:30:00Z',
#      'v': 793,
#      'vw': 134.21715}),
#  Bar({   'c': 134.33,
#      'h': 134.33,
#      'l': 134.33,
#      'n': 17,
#      'o': 134.33,
#      't': '2021-01-04T11:31:00Z',
#      'v': 1298,
#      'vw': 134.324931}),
#  Bar({   'c': 134.33,
#      'h': 134.34,
#      'l': 134.33,
#      'n': 29,
#      'o': 134.33,
#      't': '2021-01-04T11:32:00Z',
#      'v': 3009,
#      'vw': 134.336919}),
#  Bar({   'c': 134.35,
#      'h': 134.35,
#      'l': 134.35,
#      'n': 6,
#      'o': 134.35,
#      't': '2021-01-04T11:34:00Z',
#      'v': 214,
#      'vw': 134.35}),
#  Bar({   'c': 134.34,
#      'h': 134.34,
#      'l': 134.34,
#      'n': 8,
#      'o': 134.34,
#      't': '2021-01-04T11:36:00Z',
#      'v': 1811,
#      'vw': 134.340304}),
#  Bar({   'c': 134.3,
#      'h': 134.3,
#      'l': 134.3,
#      'n': 29,
#      'o': 134.3,
#      't': '2021-01-04T11:37:00Z',
#      'v': 512,
#      'vw': 134.284336}),
#  Bar({   'c': 134.25,
#      'h': 134.25,
#      'l': 134.25,
#      'n': 2,
#      'o': 134.25,
#      't': '2021-01-04T11:39:00Z',
#      'v': 135,
#      'vw': 134.25}),
#  Bar({   'c': 134.2,
#      'h': 134.2,
#      'l': 134.2,
#      'n': 12,
#      'o': 134.2,
#      't': '2021-01-04T11:40:00Z',
#      'v': 687,
#      'vw': 134.207642}),
#  Bar({   'c': 134.15,
#      'h': 134.15,
#      'l': 134.15,
#      'n': 6,
#      'o': 134.15,
#      't': '2021-01-04T11:43:00Z',
#      'v': 213,
#      'vw': 134.149906}),
#  Bar({   'c': 134.15,
#      'h': 134.15,
#      'l': 134.15,
#      'n': 15,
#      'o': 134.15,
#      't': '2021-01-04T11:44:00Z',
#      'v': 395,
#      'vw': 134.154203}),
#  Bar({   'c': 134.19,
#      'h': 134.19,
#      'l': 134.19,
#      'n': 12,
#      'o': 134.19,
#      't': '2021-01-04T11:47:00Z',
#      'v': 363,
#      'vw': 134.19}),
#  Bar({   'c': 134.1,
#      'h': 134.12,
#      'l': 134.1,
#      'n': 27,
#      'o': 134.12,
#      't': '2021-01-04T11:48:00Z',
#      'v': 1377,
#      'vw': 134.133166}),
#  Bar({   'c': 134.11,
#      'h': 134.11,
#      'l': 134.1,
#      'n': 58,
#      'o': 134.1,
#      't': '2021-01-04T11:51:00Z',
#      'v': 1842,
#      'vw': 134.114897}),
#  Bar({   'c': 134.18,
#      'h': 134.18,
#      'l': 134.18,
#      'n': 3,
#      'o': 134.18,
#      't': '2021-01-04T11:52:00Z',
#      'v': 203,
#      'vw': 134.17931}),
#  Bar({   'c': 134.17,
#      'h': 134.19,
#      'l': 134.17,
#      'n': 16,
#      'o': 134.19,
#      't': '2021-01-04T11:53:00Z',
#      'v': 3241,
#      'vw': 134.181845}),
#  Bar({   'c': 134.17,
#      'h': 134.17,
#      'l': 134.1,
#      'n': 36,
#      'o': 134.15,
#      't': '2021-01-04T11:55:00Z',
#      'v': 4339,
#      'vw': 134.134008}),
#  Bar({   'c': 134.1,
#      'h': 134.12,
#      'l': 134.1,
#      'n': 13,
#      'o': 134.12,
#      't': '2021-01-04T11:56:00Z',
#      'v': 1282,
#      'vw': 134.111279}),
#  Bar({   'c': 134.02,
#      'h': 134.04,
#      'l': 133.6,
#      'n': 88,
#      'o': 134.04,
#      't': '2021-01-04T11:57:00Z',
#      'v': 7307,
#      'vw': 133.907278}),
#  Bar({   'c': 133.99,
#      'h': 133.99,
#      'l': 133.99,
#      'n': 11,
#      'o': 133.99,
#      't': '2021-01-04T11:59:00Z',
#      'v': 333,
#      'vw': 133.988709}),
#  Bar({   'c': 133.86,
#      'h': 134,
#      'l': 133.7,
#      'n': 328,
#      'o': 133.92,
#      't': '2021-01-04T12:00:00Z',
#      'v': 24313,
#      'vw': 133.891601}),
#  Bar({   'c': 133.9,
#      'h': 133.93,
#      'l': 133.85,
#      'n': 125,
#      'o': 133.85,
#      't': '2021-01-04T12:01:00Z',
#      'v': 17439,
#      'vw': 133.880503}),
#  Bar({   'c': 133.89,
#      'h': 133.9,
#      'l': 133.85,
#      'n': 177,
#      'o': 133.9,
#      't': '2021-01-04T12:02:00Z',
#      'v': 11428,
#      'vw': 133.879427}),
#  Bar({   'c': 133.7,
#      'h': 133.86,
#      'l': 133.7,
#      'n': 183,
#      'o': 133.86,
#      't': '2021-01-04T12:03:00Z',
#      'v': 13714,
#      'vw': 133.801226}),
#  Bar({   'c': 133.8,
#      'h': 133.8,
#      'l': 133.65,
#      'n': 159,
#      'o': 133.7,
#      't': '2021-01-04T12:04:00Z',
#      'v': 22370,
#      'vw': 133.709238}),
#  Bar({   'c': 133.71,
#      'h': 133.79,
#      'l': 133.7,
#      'n': 127,
#      'o': 133.74,
#      't': '2021-01-04T12:05:00Z',
#      'v': 14045,
#      'vw': 133.726776}),
#  Bar({   'c': 133.75,
#      'h': 133.75,
#      'l': 133.7,
#      'n': 95,
#      'o': 133.7,
#      't': '2021-01-04T12:06:00Z',
#      'v': 6182,
#      'vw': 133.722056}),
#  Bar({   'c': 133.75,
#      'h': 133.75,
#      'l': 133.72,
#      'n': 101,
#      'o': 133.72,
#      't': '2021-01-04T12:07:00Z',
#      'v': 25320,
#      'vw': 133.74885}),
#  Bar({   'c': 133.74,
#      'h': 133.75,
#      'l': 133.71,
#      'n': 93,
#      'o': 133.74,
#      't': '2021-01-04T12:08:00Z',
#      'v': 8188,
#      'vw': 133.742283}),
#  Bar({   'c': 133.75,
#      'h': 133.75,
#      'l': 133.71,
#      'n': 74,
#      'o': 133.73,
#      't': '2021-01-04T12:09:00Z',
#      'v': 10999,
#      'vw': 133.746984}),
#  Bar({   'c': 133.76,
#      'h': 133.77,
#      'l': 133.7,
#      'n': 170,
#      'o': 133.74,
#      't': '2021-01-04T12:10:00Z',
#      'v': 21267,
#      'vw': 133.744718}),
#  Bar({   'c': 133.71,
#      'h': 133.73,
#      'l': 133.69,
#      'n': 103,
#      'o': 133.73,
#      't': '2021-01-04T12:11:00Z',
#      'v': 5789,
#      'vw': 133.708689}),
#  Bar({   'c': 133.75,
#      'h': 133.75,
#      'l': 133.7,
#      'n': 87,
#      'o': 133.7,
#      't': '2021-01-04T12:12:00Z',
#      'v': 5567,
#      'vw': 133.716937}),
#  Bar({   'c': 133.72,
#      'h': 133.74,
#      'l': 133.72,
#      'n': 90,
#      'o': 133.74,
#      't': '2021-01-04T12:13:00Z',
#      'v': 3049,
#      'vw': 133.732129}),
#  Bar({   'c': 133.75,
#      'h': 133.75,
#      'l': 133.71,
#      'n': 112,
#      'o': 133.71,
#      't': '2021-01-04T12:14:00Z',
#      'v': 26812,
#      'vw': 133.738174}),
#  Bar({   'c': 133.75,
#      'h': 133.75,
#      'l': 133.65,
#      'n': 128,
#      'o': 133.75,
#      't': '2021-01-04T12:15:00Z',
#      'v': 9813,
#      'vw': 133.703104}),
#  Bar({   'c': 133.71,
#      'h': 133.73,
#      'l': 133.7,
#      'n': 105,
#      'o': 133.73,
#      't': '2021-01-04T12:16:00Z',
#      'v': 4683,
#      'vw': 133.711666}),
#  Bar({   'c': 133.54,
#      'h': 133.7,
#      'l': 133.54,
#      'n': 218,
#      'o': 133.7,
#      't': '2021-01-04T12:17:00Z',
#      'v': 23388,
#      'vw': 133.622857}),
#  Bar({   'c': 133.66,
#      'h': 133.66,
#      'l': 133.54,
#      'n': 93,
#      'o': 133.54,
#      't': '2021-01-04T12:18:00Z',
#      'v': 8897,
#      'vw': 133.592829}),
#  Bar({   'c': 133.72,
#      'h': 133.73,
#      'l': 133.65,
#      'n': 78,
#      'o': 133.65,
#      't': '2021-01-04T12:19:00Z',
#      'v': 16972,
#      'vw': 133.706091}),
#  Bar({   'c': 133.66,
#      'h': 133.71,
#      'l': 133.66,
#      'n': 98,
#      'o': 133.7,
#      't': '2021-01-04T12:20:00Z',
#      'v': 5625,
#      'vw': 133.69235}),
#  Bar({   'c': 133.69,
#      'h': 133.73,
#      'l': 133.65,
#      'n': 87,
#      'o': 133.65,
#      't': '2021-01-04T12:21:00Z',
#      'v': 4177,
#      'vw': 133.688434}),
#  Bar({   'c': 133.7,
#      'h': 133.73,
#      'l': 133.68,
#      'n': 76,
#      'o': 133.68,
#      't': '2021-01-04T12:22:00Z',
#      'v': 2670,
#      'vw': 133.714599}),
#  Bar({   'c': 133.72,
#      'h': 133.75,
#      'l': 133.7,
#      'n': 81,
#      'o': 133.74,
#      't': '2021-01-04T12:23:00Z',
#      'v': 2970,
#      'vw': 133.726495}),
#  Bar({   'c': 133.7,
#      'h': 133.72,
#      'l': 133.67,
#      'n': 104,
#      'o': 133.68,
#      't': '2021-01-04T12:24:00Z',
#      'v': 5308,
#      'vw': 133.699734}),
#  Bar({   'c': 133.7,
#      'h': 133.72,
#      'l': 133.7,
#      'n': 76,
#      'o': 133.7,
#      't': '2021-01-04T12:25:00Z',
#      'v': 3650,
#      'vw': 133.700616}),
#  Bar({   'c': 133.7,
#      'h': 133.7,
#      'l': 133.66,
#      'n': 85,
#      'o': 133.69,
#      't': '2021-01-04T12:26:00Z',
#      'v': 9801,
#      'vw': 133.695258}),
#  Bar({   'c': 133.7,
#      'h': 133.7,
#      'l': 133.7,
#      'n': 51,
#      'o': 133.7,
#      't': '2021-01-04T12:27:00Z',
#      'v': 1362,
#      'vw': 133.698179}),
#  Bar({   'c': 133.71,
#      'h': 133.76,
#      'l': 133.71,
#      'n': 109,
#      'o': 133.71,
#      't': '2021-01-04T12:28:00Z',
#      'v': 6988,
#      'vw': 133.736996}),
#  Bar({   'c': 133.74,
#      'h': 133.74,
#      'l': 133.74,
#      'n': 21,
#      'o': 133.74,
#      't': '2021-01-04T12:29:00Z',
#      'v': 239,
#      'vw': 133.735146}),
#  Bar({   'c': 133.77,
#      'h': 133.79,
#      'l': 133.75,
#      'n': 59,
#      'o': 133.75,
#      't': '2021-01-04T12:30:00Z',
#      'v': 4815,
#      'vw': 133.772409}),
#  Bar({   'c': 133.8,
#      'h': 133.82,
#      'l': 133.78,
#      'n': 90,
#      'o': 133.78,
#      't': '2021-01-04T12:31:00Z',
#      'v': 13738,
#      'vw': 133.785845}),
#  Bar({   'c': 133.83,
#      'h': 133.87,
#      'l': 133.81,
#      'n': 78,
#      'o': 133.81,
#      't': '2021-01-04T12:32:00Z',
#      'v': 6114,
#      'vw': 133.836024}),
#  Bar({   'c': 133.92,
#      'h': 133.98,
#      'l': 133.85,
#      'n': 118,
#      'o': 133.85,
#      't': '2021-01-04T12:33:00Z',
#      'v': 11071,
#      'vw': 133.90754}),
#  Bar({   'c': 133.96,
#      'h': 133.97,
#      'l': 133.9,
#      'n': 82,
#      'o': 133.91,
#      't': '2021-01-04T12:34:00Z',
#      'v': 6285,
#      'vw': 133.933669}),
#  Bar({   'c': 133.96,
#      'h': 133.97,
#      'l': 133.96,
#      'n': 64,
#      'o': 133.97,
#      't': '2021-01-04T12:35:00Z',
#      'v': 7846,
#      'vw': 133.963134}),
#  Bar({   'c': 133.9,
#      'h': 133.98,
#      'l': 133.9,
#      'n': 131,
#      'o': 133.96,
#      't': '2021-01-04T12:36:00Z',
#      'v': 22832,
#      'vw': 133.952295}),
#  Bar({   'c': 133.85,
#      'h': 133.92,
#      'l': 133.85,
#      'n': 70,
#      'o': 133.9,
#      't': '2021-01-04T12:37:00Z',
#      'v': 5089,
#      'vw': 133.89529}),
#  Bar({   'c': 133.9,
#      'h': 133.94,
#      'l': 133.87,
#      'n': 59,
#      'o': 133.87,
#      't': '2021-01-04T12:38:00Z',
#      'v': 5757,
#      'vw': 133.900365}),
#  Bar({   'c': 133.9,
#      'h': 133.94,
#      'l': 133.9,
#      'n': 79,
#      'o': 133.9,
#      't': '2021-01-04T12:39:00Z',
#      'v': 3360,
#      'vw': 133.917107}),
#  Bar({   'c': 133.93,
#      'h': 133.93,
#      'l': 133.87,
#      'n': 66,
#      'o': 133.9,
#      't': '2021-01-04T12:40:00Z',
#      'v': 5629,
#      'vw': 133.917694}),
#  Bar({   'c': 133.95,
#      'h': 133.96,
#      'l': 133.93,
#      'n': 53,
#      'o': 133.93,
#      't': '2021-01-04T12:41:00Z',
#      'v': 3616,
#      'vw': 133.947478}),
#  Bar({   'c': 133.94,
#      'h': 133.94,
#      'l': 133.91,
#      'n': 58,
#      'o': 133.94,
#      't': '2021-01-04T12:42:00Z',
#      'v': 3582,
#      'vw': 133.925617}),
#  Bar({   'c': 133.87,
#      'h': 133.91,
#      'l': 133.87,
#      'n': 77,
#      'o': 133.91,
#      't': '2021-01-04T12:43:00Z',
#      'v': 1001,
#      'vw': 133.90019}),
#  Bar({   'c': 133.85,
#      'h': 133.87,
#      'l': 133.85,
#      'n': 50,
#      'o': 133.87,
#      't': '2021-01-04T12:44:00Z',
#      'v': 1259,
#      'vw': 133.864861}),
#  Bar({   'c': 133.9,
#      'h': 133.9,
#      'l': 133.86,
#      'n': 34,
#      'o': 133.86,
#      't': '2021-01-04T12:45:00Z',
#      'v': 2230,
#      'vw': 133.879009}),
#  Bar({   'c': 133.84,
#      'h': 133.87,
#      'l': 133.82,
#      'n': 114,
#      'o': 133.87,
#      't': '2021-01-04T12:46:00Z',
#      'v': 5380,
#      'vw': 133.835446}),
#  Bar({   'c': 133.8,
#      'h': 133.83,
#      'l': 133.75,
#      'n': 224,
#      'o': 133.82,
#      't': '2021-01-04T12:47:00Z',
#      'v': 7295,
#      'vw': 133.781253}),
#  Bar({   'c': 133.9,
#      'h': 133.9,
#      'l': 133.82,
#      'n': 50,
#      'o': 133.82,
#      't': '2021-01-04T12:48:00Z',
#      'v': 6162,
#      'vw': 133.829249}),
#  Bar({   'c': 133.86,
#      'h': 133.86,
#      'l': 133.83,
#      'n': 76,
#      'o': 133.85,
#      't': '2021-01-04T12:49:00Z',
#      'v': 3606,
#      'vw': 133.841129}),
#  Bar({   'c': 133.95,
#      'h': 133.95,
#      'l': 133.86,
#      'n': 80,
#      'o': 133.86,
#      't': '2021-01-04T12:50:00Z',
#      'v': 4600,
#      'vw': 133.897983}),
#  Bar({   'c': 133.96,
#      'h': 133.96,
#      'l': 133.92,
#      'n': 56,
#      'o': 133.95,
#      't': '2021-01-04T12:51:00Z',
#      'v': 3986,
#      'vw': 133.947998}),
#  Bar({   'c': 133.89,
#      'h': 133.97,
#      'l': 133.87,
#      'n': 76,
#      'o': 133.97,
#      't': '2021-01-04T12:52:00Z',
#      'v': 2852,
#      'vw': 133.927525}),
#  Bar({   'c': 133.9,
#      'h': 133.96,
#      'l': 133.9,
#      'n': 69,
#      'o': 133.9,
#      't': '2021-01-04T12:53:00Z',
#      'v': 13138,
#      'vw': 133.918994}),
#  Bar({   'c': 133.92,
#      'h': 133.94,
#      'l': 133.92,
#      'n': 34,
#      'o': 133.94,
#      't': '2021-01-04T12:54:00Z',
#      'v': 1709,
#      'vw': 133.935196}),
#  Bar({   'c': 133.91,
#      'h': 133.96,
#      'l': 133.9,
#      'n': 109,
#      'o': 133.92,
#      't': '2021-01-04T12:55:00Z',
#      'v': 8190,
#      'vw': 133.916889}),
#  Bar({   'c': 133.94,
#      'h': 133.95,
#      'l': 133.91,
#      'n': 52,
#      'o': 133.91,
#      't': '2021-01-04T12:56:00Z',
#      'v': 1725,
#      'vw': 133.930099}),
#  Bar({   'c': 133.92,
#      'h': 133.94,
#      'l': 133.91,
#      'n': 56,
#      'o': 133.93,
#      't': '2021-01-04T12:57:00Z',
#      'v': 2316,
#      'vw': 133.923765}),
#  Bar({   'c': 133.93,
#      'h': 133.94,
#      'l': 133.92,
#      'n': 60,
#      'o': 133.92,
#      't': '2021-01-04T12:58:00Z',
#      'v': 2587,
#      'vw': 133.928813}),
#  Bar({   'c': 133.95,
#      'h': 133.95,
#      'l': 133.91,
#      'n': 72,
#      'o': 133.95,
#      't': '2021-01-04T12:59:00Z',
#      'v': 4099,
#      'vw': 133.929668}),
#  Bar({   'c': 133.92,
#      'h': 133.99,
#      'l': 133.53,
#      'n': 822,
#      'o': 133.93,
#      't': '2021-01-04T13:00:00Z',
#      'v': 147837,
#      'vw': 133.802149}),
#  Bar({   'c': 133.9,
#      'h': 133.93,
#      'l': 133.9,
#      'n': 98,
#      'o': 133.92,
#      't': '2021-01-04T13:01:00Z',
#      'v': 4498,
#      'vw': 133.910825}),
#  Bar({   'c': 133.93,
#      'h': 133.93,
#      'l': 133.83,
#      'n': 247,
#      'o': 133.87,
#      't': '2021-01-04T13:02:00Z',
#      'v': 7727,
#      'vw': 133.868535}),
#  Bar({   'c': 133.9,
#      'h': 133.91,
#      'l': 133.86,
#      'n': 79,
#      'o': 133.88,
#      't': '2021-01-04T13:03:00Z',
#      'v': 5682,
#      'vw': 133.88116}),
#  Bar({   'c': 133.87,
#      'h': 133.8998,
#      'l': 133.86,
#      'n': 58,
#      'o': 133.88,
#      't': '2021-01-04T13:04:00Z',
#      'v': 2868,
#      'vw': 133.878693}),
#  Bar({   'c': 134.04,
#      'h': 134.09,
#      'l': 133.89,
#      'n': 320,
#      'o': 133.89,
#      't': '2021-01-04T13:05:00Z',
#      'v': 48657,
#      'vw': 133.978858}),
#  Bar({   'c': 134.05,
#      'h': 134.1,
#      'l': 134,
#      'n': 108,
#      'o': 134.01,
#      't': '2021-01-04T13:06:00Z',
#      'v': 48610,
#      'vw': 134.047329}),
#  Bar({   'c': 134,
#      'h': 134.04,
#      'l': 133.91,
#      'n': 120,
#      'o': 134.04,
#      't': '2021-01-04T13:07:00Z',
#      'v': 9807,
#      'vw': 133.992448}),
#  Bar({   'c': 134.02,
#      'h': 134.05,
#      'l': 134,
#      'n': 76,
#      'o': 134.02,
#      't': '2021-01-04T13:08:00Z',
#      'v': 6934,
#      'vw': 134.02575}),
#  Bar({   'c': 134.03,
#      'h': 134.07,
#      'l': 134.01,
#      'n': 93,
#      'o': 134.02,
#      't': '2021-01-04T13:09:00Z',
#      'v': 12260,
#      'vw': 134.04189}),
#  Bar({   'c': 134,
#      'h': 134.05,
#      'l': 134,
#      'n': 81,
#      'o': 134.05,
#      't': '2021-01-04T13:10:00Z',
#      'v': 5348,
#      'vw': 134.031232}),
#  Bar({   'c': 133.9998,
#      'h': 134.03,
#      'l': 133.97,
#      'n': 143,
#      'o': 134.03,
#      't': '2021-01-04T13:11:00Z',
#      'v': 5205,
#      'vw': 134.002863}),
#  Bar({   'c': 134,
#      'h': 134,
#      'l': 133.99,
#      'n': 56,
#      'o': 133.99,
#      't': '2021-01-04T13:12:00Z',
#      'v': 2675,
#      'vw': 133.997163}),
#  Bar({   'c': 134,
#      'h': 134.01,
#      'l': 133.97,
#      'n': 62,
#      'o': 133.97,
#      't': '2021-01-04T13:13:00Z',
#      'v': 4846,
#      'vw': 134.000596}),
#  Bar({   'c': 134.02,
#      'h': 134.02,
#      'l': 134.02,
#      'n': 47,
#      'o': 134.02,
#      't': '2021-01-04T13:14:00Z',
#      'v': 1964,
#      'vw': 134.018651}),
#  Bar({   'c': 134.02,
#      'h': 134.04,
#      'l': 134,
#      'n': 89,
#      'o': 134.01,
#      't': '2021-01-04T13:15:00Z',
#      'v': 6271,
#      'vw': 134.017106}),
#  Bar({   'c': 134.02,
#      'h': 134.02,
#      'l': 134.02,
#      'n': 57,
#      'o': 134.02,
#      't': '2021-01-04T13:16:00Z',
#      'v': 3073,
#      'vw': 134.024113}),
#  Bar({   'c': 134,
#      'h': 134.02,
#      'l': 133.9998,
#      'n': 126,
#      'o': 134,
#      't': '2021-01-04T13:17:00Z',
#      'v': 11473,
#      'vw': 134.002448}),
#  Bar({   'c': 133.99,
#      'h': 134.02,
#      'l': 133.99,
#      'n': 83,
#      'o': 134.01,
#      't': '2021-01-04T13:18:00Z',
#      'v': 3634,
#      'vw': 133.999073}),
#  Bar({   'c': 133.95,
#      'h': 133.98,
#      'l': 133.95,
#      'n': 99,
#      'o': 133.98,
#      't': '2021-01-04T13:19:00Z',
#      'v': 4038,
#      'vw': 133.961071}),
#  Bar({   'c': 133.94,
#      'h': 133.97,
#      'l': 133.91,
#      'n': 192,
#      'o': 133.95,
#      't': '2021-01-04T13:20:00Z',
#      'v': 7300,
#      'vw': 133.934486}),
#  Bar({   'c': 133.9,
#      'h': 133.97,
#      'l': 133.9,
#      'n': 166,
#      'o': 133.97,
#      't': '2021-01-04T13:21:00Z',
#      'v': 3710,
#      'vw': 133.932814}),
#  Bar({   'c': 133.95,
#      'h': 133.95,
#      'l': 133.9,
#      'n': 230,
#      'o': 133.95,
#      't': '2021-01-04T13:22:00Z',
#      'v': 6999,
#      'vw': 133.912584}),
#  Bar({   'c': 133.88,
#      'h': 133.93,
#      'l': 133.88,
#      'n': 133,
#      'o': 133.92,
#      't': '2021-01-04T13:23:00Z',
#      'v': 3541,
#      'vw': 133.910185}),
#  Bar({   'c': 133.87,
#      'h': 133.9,
#      'l': 133.85,
#      'n': 162,
#      'o': 133.89,
#      't': '2021-01-04T13:24:00Z',
#      'v': 4674,
#      'vw': 133.861536}),
#  Bar({   'c': 133.85,
#      'h': 133.88,
#      'l': 133.85,
#      'n': 121,
#      'o': 133.86,
#      't': '2021-01-04T13:25:00Z',
#      'v': 8281,
#      'vw': 133.867221}),
#  Bar({   'c': 133.9,
#      'h': 133.9,
#      'l': 133.84,
#      'n': 106,
#      'o': 133.86,
#      't': '2021-01-04T13:26:00Z',
#      'v': 4916,
#      'vw': 133.862501}),
#  Bar({   'c': 133.89,
#      'h': 133.93,
#      'l': 133.85,
#      'n': 122,
#      'o': 133.92,
#      't': '2021-01-04T13:27:00Z',
#      'v': 4695,
#      'vw': 133.876903}),
#  Bar({   'c': 133.86,
#      'h': 133.89,
#      'l': 133.85,
#      'n': 136,
#      'o': 133.89,
#      't': '2021-01-04T13:28:00Z',
#      'v': 6041,
#      'vw': 133.865973}),
#  Bar({   'c': 133.8,
#      'h': 133.87,
#      'l': 133.76,
#      'n': 299,
#      'o': 133.86,
#      't': '2021-01-04T13:29:00Z',
#      'v': 17647,
#      'vw': 133.808711}),
#  Bar({   'c': 133.77,
#      'h': 133.8,
#      'l': 133.77,
#      'n': 122,
#      'o': 133.79,
#      't': '2021-01-04T13:30:00Z',
#      'v': 2899,
#      'vw': 133.789143}),
#  Bar({   'c': 133.75,
#      'h': 133.79,
#      'l': 133.75,
#      'n': 169,
#      'o': 133.78,
#      't': '2021-01-04T13:31:00Z',
#      'v': 11091,
#      'vw': 133.766758}),
#  Bar({   'c': 133.75,
#      'h': 133.75,
#      'l': 133.71,
#      'n': 151,
#      'o': 133.7398,
#      't': '2021-01-04T13:32:00Z',
#      'v': 6133,
#      'vw': 133.739685}),
#  Bar({   'c': 133.8,
#      'h': 133.8,
#      'l': 133.75,
#      'n': 86,
#      'o': 133.76,
#      't': '2021-01-04T13:33:00Z',
#      'v': 5924,
#      'vw': 133.761403}),
#  Bar({   'c': 133.79,
#      'h': 133.82,
#      'l': 133.77,
#      'n': 101,
#      'o': 133.78,
#      't': '2021-01-04T13:34:00Z',
#      'v': 3288,
#      'vw': 133.79328}),
#  Bar({   'c': 133.81,
#      'h': 133.81,
#      'l': 133.77,
#      'n': 125,
#      'o': 133.79,
#      't': '2021-01-04T13:35:00Z',
#      'v': 7367,
#      'vw': 133.790417}),
#  Bar({   'c': 133.84,
#      'h': 133.87,
#      'l': 133.83,
#      'n': 105,
#      'o': 133.83,
#      't': '2021-01-04T13:36:00Z',
#      'v': 4793,
#      'vw': 133.849975}),
#  Bar({   'c': 133.84,
#      'h': 133.87,
#      'l': 133.83,
#      'n': 118,
#      'o': 133.84,
#      't': '2021-01-04T13:37:00Z',
#      'v': 7810,
#      'vw': 133.852806}),
#  Bar({   'c': 133.83,
#      'h': 133.84,
#      'l': 133.8,
#      'n': 111,
#      'o': 133.84,
#      't': '2021-01-04T13:38:00Z',
#      'v': 6937,
#      'vw': 133.819116}),
#  Bar({   'c': 133.83,
#      'h': 133.87,
#      'l': 133.8298,
#      'n': 69,
#      'o': 133.84,
#      't': '2021-01-04T13:39:00Z',
#      'v': 1768,
#      'vw': 133.840328}),
#  Bar({   'c': 133.83,
#      'h': 133.85,
#      'l': 133.8,
#      'n': 173,
#      'o': 133.83,
#      't': '2021-01-04T13:40:00Z',
#      'v': 9478,
#      'vw': 133.820216}),
#  Bar({   'c': 133.86,
#      'h': 133.86,
#      'l': 133.83,
#      'n': 120,
#      'o': 133.85,
#      't': '2021-01-04T13:41:00Z',
#      'v': 10323,
#      'vw': 133.843773}),
#  Bar({   'c': 133.89,
#      'h': 133.89,
#      'l': 133.86,
#      'n': 95,
#      'o': 133.86,
#      't': '2021-01-04T13:42:00Z',
#      'v': 9978,
#      'vw': 133.870175}),
#  Bar({   'c': 133.9,
#      'h': 133.9,
#      'l': 133.89,
#      'n': 74,
#      'o': 133.89,
#      't': '2021-01-04T13:43:00Z',
#      'v': 4254,
#      'vw': 133.896831}),
#  Bar({   'c': 133.86,
#      'h': 133.9,
#      'l': 133.86,
#      'n': 94,
#      'o': 133.89,
#      't': '2021-01-04T13:44:00Z',
#      'v': 4154,
#      'vw': 133.878358}),
#  Bar({   'c': 133.87,
#      'h': 133.87,
#      'l': 133.86,
#      'n': 98,
#      'o': 133.86,
#      't': '2021-01-04T13:45:00Z',
#      'v': 3448,
#      'vw': 133.863499}),
#  Bar({   'c': 133.78,
#      'h': 133.8601,
#      'l': 133.75,
#      'n': 282,
#      'o': 133.8601,
#      't': '2021-01-04T13:46:00Z',
#      'v': 11837,
#      'vw': 133.804992}),
#  Bar({   'c': 133.77,
#      'h': 133.8,
#      'l': 133.75,
#      'n': 83,
#      'o': 133.8,
#      't': '2021-01-04T13:47:00Z',
#      'v': 3674,
#      'vw': 133.774077}),
#  Bar({   'c': 133.78,
#      'h': 133.78,
#      'l': 133.76,
#      'n': 57,
#      'o': 133.77,
#      't': '2021-01-04T13:48:00Z',
#      'v': 1308,
#      'vw': 133.77075}),
#  Bar({   'c': 133.77,
#      'h': 133.78,
#      'l': 133.76,
#      'n': 87,
#      'o': 133.76,
#      't': '2021-01-04T13:49:00Z',
#      'v': 4304,
#      'vw': 133.772487}),
#  Bar({   'c': 133.79,
#      'h': 133.8,
#      'l': 133.76,
#      'n': 94,
#      'o': 133.78,
#      't': '2021-01-04T13:50:00Z',
#      'v': 4318,
#      'vw': 133.782484}),
#  Bar({   'c': 133.8099,
#      'h': 133.8099,
#      'l': 133.78,
#      'n': 78,
#      'o': 133.78,
#      't': '2021-01-04T13:51:00Z',
#      'v': 4355,
#      'vw': 133.799852}),
#  Bar({   'c': 133.76,
#      'h': 133.8,
#      'l': 133.75,
#      'n': 213,
#      'o': 133.8,
#      't': '2021-01-04T13:52:00Z',
#      'v': 6301,
#      'vw': 133.76992}),
#  Bar({   'c': 133.76,
#      'h': 133.79,
#      'l': 133.76,
#      'n': 87,
#      'o': 133.79,
#      't': '2021-01-04T13:53:00Z',
#      'v': 2077,
#      'vw': 133.777292}),
#  Bar({   'c': 133.76,
#      'h': 133.78,
#      'l': 133.76,
#      'n': 84,
#      'o': 133.76,
#      't': '2021-01-04T13:54:00Z',
#      'v': 2689,
#      'vw': 133.766604}),
#  Bar({   'c': 133.7698,
#      'h': 133.7698,
#      'l': 133.76,
#      'n': 100,
#      'o': 133.76,
#      't': '2021-01-04T13:55:00Z',
#      'v': 2350,
#      'vw': 133.762543}),
#  Bar({   'c': 133.7301,
#      'h': 133.78,
#      'l': 133.7301,
#      'n': 195,
#      'o': 133.76,
#      't': '2021-01-04T13:56:00Z',
#      'v': 13230,
#      'vw': 133.752783}),
#  Bar({   'c': 133.8,
#      'h': 133.8,
#      'l': 133.73,
#      'n': 228,
#      'o': 133.73,
#      't': '2021-01-04T13:57:00Z',
#      'v': 16088,
#      'vw': 133.770804}),
#  Bar({   'c': 133.8,
#      'h': 133.83,
#      'l': 133.76,
#      'n': 263,
#      'o': 133.8,
#      't': '2021-01-04T13:58:00Z',
#      'v': 12367,
#      'vw': 133.80157}),
#  Bar({   'c': 133.83,
#      'h': 133.83,
#      'l': 133.77,
#      'n': 108,
#      'o': 133.771,
#      't': '2021-01-04T13:59:00Z',
#      'v': 4844,
#      'vw': 133.790945}),
#  Bar({   'c': 133.81,
#      'h': 133.85,
#      'l': 133.8,
#      'n': 229,
#      'o': 133.83,
#      't': '2021-01-04T14:00:00Z',
#      'v': 12896,
#      'vw': 133.823683}),
#  Bar({   'c': 133.87,
#      'h': 133.87,
#      'l': 133.81,
#      'n': 175,
#      'o': 133.84,
#      't': '2021-01-04T14:01:00Z',
#      'v': 6350,
#      'vw': 133.836557}),
#  Bar({   'c': 133.85,
#      'h': 133.87,
#      'l': 133.85,
#      'n': 197,
#      'o': 133.85,
#      't': '2021-01-04T14:02:00Z',
#      'v': 13444,
#      'vw': 133.860246}),
#  Bar({   'c': 133.8,
#      'h': 133.87,
#      'l': 133.8,
#      'n': 237,
#      'o': 133.87,
#      't': '2021-01-04T14:03:00Z',
#      'v': 6835,
#      'vw': 133.825701}),
#  Bar({   'c': 133.76,
#      'h': 133.81,
#      'l': 133.76,
#      'n': 304,
#      'o': 133.8,
#      't': '2021-01-04T14:04:00Z',
#      'v': 6749,
#      'vw': 133.787434}),
#  Bar({   'c': 133.66,
#      'h': 133.75,
#      'l': 133.66,
#      'n': 625,
#      'o': 133.75,
#      't': '2021-01-04T14:05:00Z',
#      'v': 17956,
#      'vw': 133.702105}),
#  Bar({   'c': 133.6,
#      'h': 133.68,
#      'l': 133.56,
#      'n': 468,
#      'o': 133.66,
#      't': '2021-01-04T14:06:00Z',
#      'v': 27513,
#      'vw': 133.606315}),
#  Bar({   'c': 133.63,
#      'h': 133.65,
#      'l': 133.6,
#      'n': 238,
#      'o': 133.62,
#      't': '2021-01-04T14:07:00Z',
#      'v': 7832,
#      'vw': 133.61299}),
#  Bar({   'c': 133.55,
#      'h': 133.6299,
#      'l': 133.51,
#      'n': 317,
#      'o': 133.6299,
#      't': '2021-01-04T14:08:00Z',
#      'v': 9506,
#      'vw': 133.574353}),
#  Bar({   'c': 133.55,
#      'h': 133.57,
#      'l': 133.5201,
#      'n': 180,
#      'o': 133.5201,
#      't': '2021-01-04T14:09:00Z',
#      'v': 8725,
#      'vw': 133.557338}),
#  Bar({   'c': 133.6,
#      'h': 133.6,
#      'l': 133.55,
#      'n': 236,
#      'o': 133.57,
#      't': '2021-01-04T14:10:00Z',
#      'v': 18168,
#      'vw': 133.564339}),
#  Bar({   'c': 133.55,
#      'h': 133.6,
#      'l': 133.55,
#      'n': 230,
#      'o': 133.6,
#      't': '2021-01-04T14:11:00Z',
#      'v': 11605,
#      'vw': 133.570472}),
#  Bar({   'c': 133.57,
#      'h': 133.57,
#      'l': 133.53,
#      'n': 245,
#      'o': 133.56,
#      't': '2021-01-04T14:12:00Z',
#      'v': 6912,
#      'vw': 133.547273}),
#  Bar({   'c': 133.56,
#      'h': 133.58,
#      'l': 133.53,
#      'n': 221,
#      'o': 133.57,
#      't': '2021-01-04T14:13:00Z',
#      'v': 14405,
#      'vw': 133.558879}),
#  Bar({   'c': 133.53,
#      'h': 133.55,
#      'l': 133.52,
#      'n': 218,
#      'o': 133.55,
#      't': '2021-01-04T14:14:00Z',
#      'v': 7419,
#      'vw': 133.534772}),
#  Bar({   'c': 133.5,
#      'h': 133.53,
#      'l': 133.49,
#      'n': 529,
#      'o': 133.53,
#      't': '2021-01-04T14:15:00Z',
#      'v': 24917,
#      'vw': 133.507192}),
#  Bar({   'c': 133.44,
#      'h': 133.5198,
#      'l': 133.43,
#      'n': 262,
#      'o': 133.49,
#      't': '2021-01-04T14:16:00Z',
#      'v': 16015,
#      'vw': 133.496}),
#  Bar({   'c': 133.39,
#      'h': 133.44,
#      'l': 133.35,
#      'n': 342,
#      'o': 133.44,
#      't': '2021-01-04T14:17:00Z',
#      'v': 12444,
#      'vw': 133.394699}),
#  Bar({   'c': 133.53,
#      'h': 133.54,
#      'l': 133.4198,
#      'n': 238,
#      'o': 133.43,
#      't': '2021-01-04T14:18:00Z',
#      'v': 30142,
#      'vw': 133.46985}),
#  Bar({   'c': 133.47,
#      'h': 133.54,
#      'l': 133.42,
#      'n': 256,
#      'o': 133.54,
#      't': '2021-01-04T14:19:00Z',
#      'v': 10412,
#      'vw': 133.474304}),
#  Bar({   'c': 133.55,
#      'h': 133.55,
#      'l': 133.42,
#      'n': 196,
#      'o': 133.42,
#      't': '2021-01-04T14:20:00Z',
#      'v': 6145,
#      'vw': 133.501069}),
#  Bar({   'c': 133.58,
#      'h': 133.58,
#      'l': 133.54,
#      'n': 166,
#      'o': 133.54,
#      't': '2021-01-04T14:21:00Z',
#      'v': 8025,
#      'vw': 133.559414}),
#  Bar({   'c': 133.62,
#      'h': 133.65,
#      'l': 133.5702,
#      'n': 189,
#      'o': 133.5702,
#      't': '2021-01-04T14:22:00Z',
#      'v': 9763,
#      'vw': 133.598982}),
#  Bar({   'c': 133.5998,
#      'h': 133.65,
#      'l': 133.57,
#      'n': 238,
#      'o': 133.65,
#      't': '2021-01-04T14:23:00Z',
#      'v': 8946,
#      'vw': 133.61727}),
#  Bar({   'c': 133.59,
#      'h': 133.61,
#      'l': 133.57,
#      'n': 203,
#      'o': 133.57,
#      't': '2021-01-04T14:24:00Z',
#      'v': 18516,
#      'vw': 133.591606}),
#  Bar({   'c': 133.59,
#      'h': 133.6,
#      'l': 133.58,
#      'n': 128,
#      'o': 133.6,
#      't': '2021-01-04T14:25:00Z',
#      'v': 3224,
#      'vw': 133.587258}),
#  Bar({   'c': 133.6,
#      'h': 133.6,
#      'l': 133.57,
#      'n': 233,
#      'o': 133.59,
#      't': '2021-01-04T14:26:00Z',
#      'v': 8742,
#      'vw': 133.582147}),
#  Bar({   'c': 133.6,
#      'h': 133.6,
#      'l': 133.58,
#      'n': 145,
#      'o': 133.58,
#      't': '2021-01-04T14:27:00Z',
#      'v': 6579,
#      'vw': 133.588173}),
#  Bar({   'c': 133.6,
#      'h': 133.64,
#      'l': 133.57,
#      'n': 214,
#      'o': 133.6,
#      't': '2021-01-04T14:28:00Z',
#      'v': 18138,
#      'vw': 133.60048}),
#  Bar({   'c': 133.52,
#      'h': 133.59,
#      'l': 133.52,
#      'n': 387,
#      'o': 133.56,
#      't': '2021-01-04T14:29:00Z',
#      'v': 5110,
#      'vw': 133.561591}),
#  Bar({   'c': 133.15,
#      'h': 133.6116,
#      'l': 132.95,
#      'n': 12818,
#      'o': 133.52,
#      't': '2021-01-04T14:30:00Z',
#      'v': 2476730,
#      'vw': 133.441818}),
#  Bar({   'c': 133.335,
#      'h': 133.45,
#      'l': 133.08,
#      'n': 4215,
#      'o': 133.13,
#      't': '2021-01-04T14:31:00Z',
#      'v': 534463,
#      'vw': 133.294378}),
#  Bar({   'c': 133.11,
#      'h': 133.36,
#      'l': 132.99,
#      'n': 4818,
#      'o': 133.345,
#      't': '2021-01-04T14:32:00Z',
#      'v': 526051,
#      'vw': 133.160532}),
#  Bar({   'c': 132.7462,
#      'h': 133.15,
#      'l': 132.71,
#      'n': 6802,
#      'o': 133.11,
#      't': '2021-01-04T14:33:00Z',
#      'v': 555527,
#      'vw': 132.815607}),
#  Bar({   'c': 132.81,
#      'h': 132.83,
#      'l': 132.39,
#      'n': 9821,
#      'o': 132.76,
#      't': '2021-01-04T14:34:00Z',
#      'v': 744644,
#      'vw': 132.627858}),
#  Bar({   'c': 132.6355,
#      'h': 132.89,
#      'l': 132.6,
#      'n': 4296,
#      'o': 132.81,
#      't': '2021-01-04T14:35:00Z',
#      'v': 440511,
#      'vw': 132.754649}),
#  Bar({   'c': 132.33,
#      'h': 132.64,
#      'l': 132.27,
#      'n': 4193,
#      'o': 132.63,
#      't': '2021-01-04T14:36:00Z',
#      'v': 375245,
#      'vw': 132.431331}),
#  Bar({   'c': 132.2,
#      'h': 132.35,
#      'l': 132.13,
#      'n': 3897,
#      'o': 132.32,
#      't': '2021-01-04T14:37:00Z',
#      'v': 462655,
#      'vw': 132.235623}),
#  Bar({   'c': 131.92,
#      'h': 132.22,
#      'l': 131.81,
#      'n': 8269,
#      'o': 132.21,
#      't': '2021-01-04T14:38:00Z',
#      'v': 728915,
#      'vw': 132.006056}),
#  Bar({   'c': 131.89,
#      'h': 132.13,
#      'l': 131.88,
#      'n': 4597,
#      'o': 131.9285,
#      't': '2021-01-04T14:39:00Z',
#      'v': 534217,
#      'vw': 132.035731}),
#  Bar({   'c': 131.7334,
#      'h': 131.97,
# ...
#      'h': 129.96,
#      'l': 129.9,
#      'n': 22,
#      'o': 129.9,
#      't': '2021-01-05T09:08:00Z',
#      'v': 1184,
#      'vw': 129.916301}),
#  Bar({   'c': 129.87,
#      'h': 129.91,
#      'l': 129.87,
#      'n': 14,
#      'o': 129.91,
#      't': '2021-01-05T09:09:00Z',
#      'v': 2532,
#      'vw': 129.888464}),
#  Bar({   'c': 129.75,
#      'h': 129.9,
#      'l': 129.75,
#      'n': 33,
#      'o': 129.9,
#      't': '2021-01-05T09:10:00Z',
#      'v': 5931,
#      'vw': 129.777687}),
#  Bar({   'c': 129.86,
#      'h': 129.86,
#      'l': 129.86,
#      'n': 10,
#      'o': 129.86,
#      't': '2021-01-05T09:12:00Z',
#      'v': 565,
#      'vw': 129.859646}),
#  Bar({   'c': 129.84,
#      'h': 129.88,
#      'l': 129.84,
#      'n': 17,
#      'o': 129.88,
#      't': '2021-01-05T09:13:00Z',
#      'v': 490,
#      'vw': 129.859612}),
#  Bar({   'c': 129.89,
#      'h': 129.89,
#      'l': 129.89,
#      'n': 10,
#      'o': 129.89,
#      't': '2021-01-05T09:15:00Z',
#      'v': 362,
#      'vw': 129.88489}),
#  Bar({   'c': 129.85,
#      'h': 129.85,
#      'l': 129.85,
#      'n': 15,
#      'o': 129.85,
#      't': '2021-01-05T09:16:00Z',
#      'v': 351,
#      'vw': 129.867977}),
#  Bar({   'c': 129.9,
#      'h': 129.9,
#      'l': 129.89,
#      'n': 16,
#      'o': 129.89,
#      't': '2021-01-05T09:17:00Z',
#      'v': 734,
#      'vw': 129.896131}),
#  Bar({   'c': 129.9,
#      'h': 129.9,
#      'l': 129.9,
#      'n': 7,
#      'o': 129.9,
#      't': '2021-01-05T09:18:00Z',
#      'v': 158,
#      'vw': 129.903165}),
#  Bar({   'c': 129.95,
#      'h': 129.95,
#      'l': 129.95,
#      'n': 6,
#      'o': 129.95,
#      't': '2021-01-05T09:19:00Z',
#      'v': 115,
#      'vw': 129.949391}),
#  Bar({   'c': 129.8,
#      'h': 129.95,
#      'l': 129.8,
#      'n': 38,
#      'o': 129.95,
#      't': '2021-01-05T09:21:00Z',
#      'v': 3516,
#      'vw': 129.83779}),
#  Bar({   'c': 129.76,
#      'h': 129.76,
#      'l': 129.76,
#      'n': 16,
#      'o': 129.76,
#      't': '2021-01-05T09:24:00Z',
#      'v': 530,
#      'vw': 129.763358}),
#  Bar({   'c': 129.75,
#      'h': 129.75,
#      'l': 129.75,
#      'n': 30,
#      'o': 129.75,
#      't': '2021-01-05T09:26:00Z',
#      'v': 3882,
#      'vw': 129.751182}),
#  Bar({   'c': 129.75,
#      'h': 129.75,
#      'l': 129.75,
#      'n': 6,
#      'o': 129.75,
#      't': '2021-01-05T09:27:00Z',
#      'v': 588,
#      'vw': 129.75017}),
#  Bar({   'c': 129.8,
#      'h': 129.8,
#      'l': 129.76,
#      'n': 20,
#      'o': 129.76,
#      't': '2021-01-05T09:28:00Z',
#      'v': 1518,
#      'vw': 129.767358}),
#  Bar({   'c': 129.83,
#      'h': 129.83,
#      'l': 129.83,
#      'n': 12,
#      'o': 129.83,
#      't': '2021-01-05T09:30:00Z',
#      'v': 451,
#      'vw': 129.843703}),
#  Bar({   'c': 129.83,
#      'h': 129.83,
#      'l': 129.83,
#      'n': 4,
#      'o': 129.83,
#      't': '2021-01-05T09:32:00Z',
#      'v': 112,
#      'vw': 129.828393}),
#  Bar({   'c': 129.83,
#      'h': 129.83,
#      'l': 129.81,
#      'n': 5,
#      'o': 129.81,
#      't': '2021-01-05T09:33:00Z',
#      'v': 724,
#      'vw': 129.826878}),
#  Bar({   'c': 129.85,
#      'h': 129.85,
#      'l': 129.85,
#      'n': 10,
#      'o': 129.85,
#      't': '2021-01-05T09:34:00Z',
#      'v': 307,
#      'vw': 129.8457}),
#  Bar({   'c': 129.9,
#      'h': 129.9,
#      'l': 129.89,
#      'n': 5,
#      'o': 129.89,
#      't': '2021-01-05T09:35:00Z',
#      'v': 257,
#      'vw': 129.893969}),
#  Bar({   'c': 129.95,
#      'h': 129.95,
#      'l': 129.95,
#      'n': 9,
#      'o': 129.95,
#      't': '2021-01-05T09:36:00Z',
#      'v': 680,
#      'vw': 129.932838}),
#  Bar({   'c': 130,
#      'h': 130,
#      'l': 129.95,
#      'n': 23,
#      'o': 129.96,
#      't': '2021-01-05T09:37:00Z',
#      'v': 1354,
#      'vw': 129.964409}),
#  Bar({   'c': 130,
#      'h': 130,
#      'l': 130,
#      'n': 20,
#      'o': 130,
#      't': '2021-01-05T09:38:00Z',
#      'v': 2559,
#      'vw': 130}),
#  Bar({   'c': 130.08,
#      'h': 130.08,
#      'l': 130.02,
#      'n': 23,
#      'o': 130.02,
#      't': '2021-01-05T09:39:00Z',
#      'v': 1007,
#      'vw': 130.065402}),
#  Bar({   'c': 130.08,
#      'h': 130.08,
#      'l': 130.08,
#      'n': 7,
#      'o': 130.08,
#      't': '2021-01-05T09:40:00Z',
#      'v': 183,
#      'vw': 130.101148}),
#  Bar({   'c': 130.07,
#      'h': 130.07,
#      'l': 130.07,
#      'n': 4,
#      'o': 130.07,
#      't': '2021-01-05T09:41:00Z',
#      'v': 215,
#      'vw': 130.070698}),
#  Bar({   'c': 130.07,
#      'h': 130.07,
#      'l': 130.07,
#      'n': 4,
#      'o': 130.07,
#      't': '2021-01-05T09:42:00Z',
#      'v': 112,
#      'vw': 130.072857}),
#  Bar({   'c': 130.2,
#      'h': 130.2,
#      'l': 130.2,
#      'n': 15,
#      'o': 130.2,
#      't': '2021-01-05T09:43:00Z',
#      'v': 1557,
#      'vw': 130.196904}),
#  Bar({   'c': 130.11,
#      'h': 130.11,
#      'l': 130.11,
#      'n': 1,
#      'o': 130.11,
#      't': '2021-01-05T09:46:00Z',
#      'v': 200,
#      'vw': 130.11}),
#  Bar({   'c': 130.09,
#      'h': 130.09,
#      'l': 130.09,
#      'n': 12,
#      'o': 130.09,
#      't': '2021-01-05T09:49:00Z',
#      'v': 375,
#      'vw': 130.09368}),
#  Bar({   'c': 130.11,
#      'h': 130.11,
#      'l': 130.08,
#      'n': 22,
#      'o': 130.08,
#      't': '2021-01-05T09:51:00Z',
#      'v': 1653,
#      'vw': 130.106497}),
#  Bar({   'c': 130.11,
#      'h': 130.11,
#      'l': 130.11,
#      'n': 6,
#      'o': 130.11,
#      't': '2021-01-05T09:52:00Z',
#      'v': 304,
#      'vw': 130.11}),
#  Bar({   'c': 130.18,
#      'h': 130.18,
#      'l': 130.11,
#      'n': 20,
#      'o': 130.18,
#      't': '2021-01-05T09:53:00Z',
#      'v': 1341,
#      'vw': 130.151999}),
#  Bar({   'c': 130.1,
#      'h': 130.2,
#      'l': 130.1,
#      'n': 20,
#      'o': 130.2,
#      't': '2021-01-05T09:54:00Z',
#      'v': 1797,
#      'vw': 130.133428}),
#  Bar({   'c': 130.2,
#      'h': 130.2,
#      'l': 130.2,
#      'n': 5,
#      'o': 130.2,
#      't': '2021-01-05T09:55:00Z',
#      'v': 862,
#      'vw': 130.199014}),
#  Bar({   'c': 130.14,
#      'h': 130.14,
#      'l': 130.14,
#      'n': 29,
#      'o': 130.14,
#      't': '2021-01-05T09:56:00Z',
#      'v': 1698,
#      'vw': 130.131078}),
#  Bar({   'c': 129.8,
#      'h': 130.04,
#      'l': 129.75,
#      'n': 56,
#      'o': 130.04,
#      't': '2021-01-05T09:58:00Z',
#      'v': 3310,
#      'vw': 129.967565}),
#  Bar({   'c': 130.02,
#      'h': 130.19,
#      'l': 129.91,
#      'n': 37,
#      'o': 129.99,
#      't': '2021-01-05T09:59:00Z',
#      'v': 5507,
#      'vw': 130.055513}),
#  Bar({   'c': 130.2,
#      'h': 130.2,
#      'l': 130.09,
#      'n': 26,
#      'o': 130.09,
#      't': '2021-01-05T10:00:00Z',
#      'v': 3198,
#      'vw': 130.16258}),
#  Bar({   'c': 130.23,
#      'h': 130.23,
#      'l': 130.11,
#      'n': 14,
#      'o': 130.12,
#      't': '2021-01-05T10:01:00Z',
#      'v': 992,
#      'vw': 130.161542}),
#  Bar({   'c': 130.23,
#      'h': 130.23,
#      'l': 130.23,
#      'n': 4,
#      'o': 130.23,
#      't': '2021-01-05T10:02:00Z',
#      'v': 282,
#      'vw': 130.187092}),
#  Bar({   'c': 130.11,
#      'h': 130.11,
#      'l': 130.11,
#      'n': 9,
#      'o': 130.11,
#      't': '2021-01-05T10:03:00Z',
#      'v': 398,
#      'vw': 130.176457}),
#  Bar({   'c': 130.23,
#      'h': 130.23,
#      'l': 130.23,
#      'n': 8,
#      'o': 130.23,
#      't': '2021-01-05T10:04:00Z',
#      'v': 171,
#      'vw': 130.227018}),
#  Bar({   'c': 130.23,
#      'h': 130.24,
#      'l': 130.23,
#      'n': 7,
#      'o': 130.24,
#      't': '2021-01-05T10:08:00Z',
#      'v': 578,
#      'vw': 130.237578}),
#  Bar({   'c': 130.26,
#      'h': 130.26,
#      'l': 130.26,
#      'n': 14,
#      'o': 130.26,
#      't': '2021-01-05T10:10:00Z',
#      'v': 631,
#      'vw': 130.258368}),
#  Bar({   'c': 130.26,
#      'h': 130.26,
#      'l': 130.26,
#      'n': 13,
#      'o': 130.26,
#      't': '2021-01-05T10:11:00Z',
#      'v': 680,
#      'vw': 130.25325}),
#  Bar({   'c': 130.23,
#      'h': 130.23,
#      'l': 130.23,
#      'n': 6,
#      'o': 130.23,
#      't': '2021-01-05T10:12:00Z',
#      'v': 270,
#      'vw': 130.244889}),
#  Bar({   'c': 130.21,
#      'h': 130.22,
#      'l': 130.21,
#      'n': 10,
#      'o': 130.22,
#      't': '2021-01-05T10:17:00Z',
#      'v': 897,
#      'vw': 130.216511}),
#  Bar({   'c': 130.12,
#      'h': 130.18,
#      'l': 130.12,
#      'n': 24,
#      'o': 130.18,
#      't': '2021-01-05T10:18:00Z',
#      'v': 882,
#      'vw': 130.143753}),
#  Bar({   'c': 130.18,
#      'h': 130.18,
#      'l': 130.15,
#      'n': 9,
#      'o': 130.15,
#      't': '2021-01-05T10:22:00Z',
#      'v': 660,
#      'vw': 130.164106}),
#  Bar({   'c': 130.16,
#      'h': 130.16,
#      'l': 130.15,
#      'n': 15,
#      'o': 130.16,
#      't': '2021-01-05T10:23:00Z',
#      'v': 2880,
#      'vw': 130.158104}),
#  Bar({   'c': 130.11,
#      'h': 130.11,
#      'l': 130.11,
#      'n': 19,
#      'o': 130.11,
#      't': '2021-01-05T10:25:00Z',
#      'v': 745,
#      'vw': 130.11294}),
#  Bar({   'c': 130.1,
#      'h': 130.1,
#      'l': 130.09,
#      'n': 10,
#      'o': 130.09,
#      't': '2021-01-05T10:32:00Z',
#      'v': 1669,
#      'vw': 130.097903}),
#  Bar({   'c': 130.04,
#      'h': 130.04,
#      'l': 130.04,
#      'n': 7,
#      'o': 130.04,
#      't': '2021-01-05T10:34:00Z',
#      'v': 142,
#      'vw': 130.044437}),
#  Bar({   'c': 130,
#      'h': 130,
#      'l': 130,
#      'n': 21,
#      'o': 130,
#      't': '2021-01-05T10:35:00Z',
#      'v': 687,
#      'vw': 130.002766}),
#  Bar({   'c': 130.04,
#      'h': 130.04,
#      'l': 130.04,
#      'n': 7,
#      'o': 130.04,
#      't': '2021-01-05T10:37:00Z',
#      'v': 573,
#      'vw': 130.048656}),
#  Bar({   'c': 130.05,
#      'h': 130.05,
#      'l': 130.05,
#      'n': 12,
#      'o': 130.05,
#      't': '2021-01-05T10:38:00Z',
#      'v': 655,
#      'vw': 130.051832}),
#  Bar({   'c': 130.09,
#      'h': 130.09,
#      'l': 130.09,
#      'n': 20,
#      'o': 130.09,
#      't': '2021-01-05T10:41:00Z',
#      'v': 2563,
#      'vw': 130.089949}),
#  Bar({   'c': 130.07,
#      'h': 130.07,
#      'l': 130.07,
#      'n': 10,
#      'o': 130.07,
#      't': '2021-01-05T10:42:00Z',
#      'v': 176,
#      'vw': 130.073523}),
#  Bar({   'c': 130.08,
#      'h': 130.08,
#      'l': 130.08,
#      'n': 10,
#      'o': 130.08,
#      't': '2021-01-05T10:44:00Z',
#      'v': 632,
#      'vw': 130.079873}),
#  Bar({   'c': 130.09,
#      'h': 130.09,
#      'l': 130.08,
#      'n': 7,
#      'o': 130.08,
#      't': '2021-01-05T10:46:00Z',
#      'v': 460,
#      'vw': 130.085087}),
#  Bar({   'c': 130,
#      'h': 130.01,
#      'l': 130,
#      'n': 31,
#      'o': 130.01,
#      't': '2021-01-05T10:48:00Z',
#      'v': 1355,
#      'vw': 130.034303}),
#  Bar({   'c': 130,
#      'h': 130.03,
#      'l': 130,
#      'n': 17,
#      'o': 130,
#      't': '2021-01-05T10:49:00Z',
#      'v': 2269,
#      'vw': 130.005522}),
#  Bar({   'c': 130,
#      'h': 130,
#      'l': 130,
#      'n': 7,
#      'o': 130,
#      't': '2021-01-05T10:50:00Z',
#      'v': 187,
#      'vw': 130.007647}),
#  Bar({   'c': 130,
#      'h': 130,
#      'l': 130,
#      'n': 6,
#      'o': 130,
#      't': '2021-01-05T10:51:00Z',
#      'v': 1168,
#      'vw': 130.000505}),
#  Bar({   'c': 129.97,
#      'h': 129.97,
#      'l': 129.97,
#      'n': 13,
#      'o': 129.97,
#      't': '2021-01-05T10:53:00Z',
#      'v': 371,
#      'vw': 129.968383}),
#  Bar({   'c': 130,
#      'h': 130,
#      'l': 130,
#      'n': 5,
#      'o': 130,
#      't': '2021-01-05T10:54:00Z',
#      'v': 128,
#      'vw': 130.004531}),
#  Bar({   'c': 130,
#      'h': 130,
#      'l': 130,
#      'n': 6,
#      'o': 130,
#      't': '2021-01-05T10:55:00Z',
#      'v': 228,
#      'vw': 130.003465}),
#  Bar({   'c': 130.2,
#      'h': 130.2,
#      'l': 130.09,
#      'n': 29,
#      'o': 130.09,
#      't': '2021-01-05T10:56:00Z',
#      'v': 6568,
#      'vw': 130.108998}),
#  Bar({   'c': 130.19,
#      'h': 130.19,
#      'l': 130.19,
#      'n': 8,
#      'o': 130.19,
#      't': '2021-01-05T10:57:00Z',
#      'v': 610,
#      'vw': 130.19}),
#  Bar({   'c': 130.12,
#      'h': 130.12,
#      'l': 130.12,
#      'n': 9,
#      'o': 130.12,
#      't': '2021-01-05T10:58:00Z',
#      'v': 406,
#      'vw': 130.151724}),
#  Bar({   'c': 130.2,
#      'h': 130.2,
#      'l': 130.19,
#      'n': 21,
#      'o': 130.19,
#      't': '2021-01-05T10:59:00Z',
#      'v': 2951,
#      'vw': 130.196788}),
#  Bar({   'c': 130.15,
#      'h': 130.2,
#      'l': 130.1,
#      'n': 26,
#      'o': 130.2,
#      't': '2021-01-05T11:00:00Z',
#      'v': 4019,
#      'vw': 130.166126}),
#  Bar({   'c': 130.15,
#      'h': 130.15,
#      'l': 130.15,
#      'n': 9,
#      'o': 130.15,
#      't': '2021-01-05T11:01:00Z',
#      'v': 328,
#      'vw': 130.15}),
#  Bar({   'c': 130.27,
#      'h': 130.27,
#      'l': 130.24,
#      'n': 14,
#      'o': 130.24,
#      't': '2021-01-05T11:04:00Z',
#      'v': 1115,
#      'vw': 130.251731}),
#  Bar({   'c': 130.26,
#      'h': 130.26,
#      'l': 130.25,
#      'n': 10,
#      'o': 130.25,
#      't': '2021-01-05T11:07:00Z',
#      'v': 419,
#      'vw': 130.25673}),
#  Bar({   'c': 130.27,
#      'h': 130.27,
#      'l': 130.27,
#      'n': 6,
#      'o': 130.27,
#      't': '2021-01-05T11:11:00Z',
#      'v': 389,
#      'vw': 130.271722}),
#  Bar({   'c': 130.22,
#      'h': 130.27,
#      'l': 130.22,
#      'n': 21,
#      'o': 130.27,
#      't': '2021-01-05T11:12:00Z',
#      'v': 932,
#      'vw': 130.236384}),
#  Bar({   'c': 130.24,
#      'h': 130.24,
#      'l': 130.24,
#      'n': 7,
#      'o': 130.24,
#      't': '2021-01-05T11:13:00Z',
#      'v': 599,
#      'vw': 130.241686}),
#  Bar({   'c': 130.23,
#      'h': 130.25,
#      'l': 130.23,
#      'n': 16,
#      'o': 130.25,
#      't': '2021-01-05T11:14:00Z',
#      'v': 894,
#      'vw': 130.243826}),
#  Bar({   'c': 130.25,
#      'h': 130.25,
#      'l': 130.25,
#      'n': 4,
#      'o': 130.25,
#      't': '2021-01-05T11:15:00Z',
#      'v': 155,
#      'vw': 130.24871}),
#  Bar({   'c': 130.27,
#      'h': 130.27,
#      'l': 130.27,
#      'n': 10,
#      'o': 130.27,
#      't': '2021-01-05T11:16:00Z',
#      'v': 206,
#      'vw': 130.270291}),
#  Bar({   'c': 130.27,
#      'h': 130.27,
#      'l': 130.27,
#      'n': 18,
#      'o': 130.27,
#      't': '2021-01-05T11:18:00Z',
#      'v': 981,
#      'vw': 130.270887}),
#  Bar({   'c': 130.2,
#      'h': 130.2,
#      'l': 130.2,
#      'n': 11,
#      'o': 130.2,
#      't': '2021-01-05T11:19:00Z',
#      'v': 342,
#      'vw': 130.232222}),
#  Bar({   'c': 130.25,
#      'h': 130.25,
#      'l': 130.25,
#      'n': 4,
#      'o': 130.25,
#      't': '2021-01-05T11:20:00Z',
#      'v': 504,
#      'vw': 130.24994}),
#  Bar({   'c': 130.25,
#      'h': 130.25,
#      'l': 130.25,
#      'n': 7,
#      'o': 130.25,
#      't': '2021-01-05T11:21:00Z',
#      'v': 336,
#      'vw': 130.25}),
#  Bar({   'c': 130.25,
#      'h': 130.25,
#      'l': 130.25,
#      'n': 3,
#      'o': 130.25,
#      't': '2021-01-05T11:23:00Z',
#      'v': 363,
#      'vw': 130.25}),
#  Bar({   'c': 130.25,
#      'h': 130.25,
#      'l': 130.25,
#      'n': 5,
#      'o': 130.25,
#      't': '2021-01-05T11:24:00Z',
#      'v': 603,
#      'vw': 130.25}),
#  Bar({   'c': 130.22,
#      'h': 130.22,
#      'l': 130.22,
#      'n': 27,
#      'o': 130.22,
#      't': '2021-01-05T11:26:00Z',
#      'v': 989,
#      'vw': 130.223205}),
#  Bar({   'c': 130.25,
#      'h': 130.27,
#      'l': 130.25,
#      'n': 10,
#      'o': 130.25,
#      't': '2021-01-05T11:28:00Z',
#      'v': 636,
#      'vw': 130.254748}),
#  Bar({   'c': 130,
#      'h': 130.25,
#      'l': 130,
#      'n': 85,
#      'o': 130.25,
#      't': '2021-01-05T11:30:00Z',
#      'v': 5963,
#      'vw': 130.053919}),
#  Bar({   'c': 130.29,
#      'h': 130.3,
#      'l': 130.24,
#      'n': 34,
#      'o': 130.24,
#      't': '2021-01-05T11:32:00Z',
#      'v': 10696,
#      'vw': 130.292095}),
#  Bar({   'c': 130,
#      'h': 130.17,
#      'l': 130,
#      'n': 40,
#      'o': 130.17,
#      't': '2021-01-05T11:34:00Z',
#      'v': 1603,
#      'vw': 130.00315}),
#  Bar({   'c': 130,
#      'h': 130,
#      'l': 130,
#      'n': 6,
#      'o': 130,
#      't': '2021-01-05T11:36:00Z',
#      'v': 204,
#      'vw': 130.006765}),
#  Bar({   'c': 129.86,
#      'h': 129.86,
#      'l': 129.75,
#      'n': 19,
#      'o': 129.85,
#      't': '2021-01-05T11:39:00Z',
#      'v': 1300,
#      'vw': 129.825692}),
#  Bar({   'c': 129.9,
#      'h': 129.9,
#      'l': 129.9,
#      'n': 4,
#      'o': 129.9,
#      't': '2021-01-05T11:40:00Z',
#      'v': 371,
#      'vw': 129.900216}),
#  Bar({   'c': 129.8,
#      'h': 129.9,
#      'l': 129.8,
#      'n': 44,
#      'o': 129.9,
#      't': '2021-01-05T11:41:00Z',
#      'v': 3247,
#      'vw': 129.828845}),
#  Bar({   'c': 129.76,
#      'h': 129.8,
#      'l': 129.76,
#      'n': 24,
#      'o': 129.8,
#      't': '2021-01-05T11:42:00Z',
#      'v': 1836,
#      'vw': 129.78598}),
#  Bar({   'c': 129.78,
#      'h': 129.78,
#      'l': 129.78,
#      'n': 7,
#      'o': 129.78,
#      't': '2021-01-05T11:43:00Z',
#      'v': 219,
#      'vw': 129.777626}),
#  ...]

# %%
import pandas as pd

# %%
pd.DataFrame([bar._raw for bar in barset])
# Out:
#                            t       o         h       l       c      v   n  \
# 0       2021-01-04T09:00:00Z  133.31  133.4900  133.02  133.49  26666  87
# 1       2021-01-04T09:01:00Z  133.49  133.4900  133.49  133.49   1240  26
# 2       2021-01-04T09:02:00Z  133.60  133.6000  133.50  133.50   1217  30
# 3       2021-01-04T09:03:00Z  133.51  133.5100  133.51  133.51    741  18
# 4       2021-01-04T09:04:00Z  133.77  133.7700  133.70  133.72   1970  30
# ...                      ...     ...       ...     ...     ...    ...  ..
# 255791  2022-03-25T23:55:00Z  174.92  174.9200  174.90  174.92    960  11
# 255792  2022-03-25T23:56:00Z  174.91  174.9200  174.90  174.90   1116  10
# 255793  2022-03-25T23:57:00Z  174.90  174.9001  174.90  174.90   1164   9
# 255794  2022-03-25T23:58:00Z  174.91  174.9200  174.91  174.92   1155  21
# 255795  2022-03-25T23:59:00Z  174.99  175.0000  174.96  175.00   4711  30
#
#                 vw
# 0       133.233024
# 1       133.490887
# 2       133.523558
# 3       133.569825
# 4       133.725553
# ...            ...
# 255791  174.912250
# 255792  174.915358
# 255793  174.900475
# 255794  174.912050
# 255795  174.987937
#
# [255796 rows x 8 columns]

# %%
dir(barset[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_raw']

# %%
barset[0]._raw
# Out:
# {'t': '2021-01-04T09:00:00Z',
#  'o': 133.31,
#  'h': 133.49,
#  'l': 133.02,
#  'c': 133.49,
#  'v': 26666,
#  'n': 87,
#  'vw': 133.233024}
